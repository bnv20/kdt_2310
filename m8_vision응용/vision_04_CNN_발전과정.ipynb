# %% [markdown]
# ## 합성곱 신경망(Convolutional Neural Networks, CNNs)의 발전 과정
#
# 초기 단계: Neocognitron
#   - 1980년대: CNN의 개념은 1980년대 초반에 후쿠시마 쿠니히코에 의해 소개된 Neocognitron에서 유래합니다. 이는 시각적 패턴을 인식하기 위한 자기조직화 신경망이었으며, 합성곱 계층과 풀링 계층의 아이디어를 도입했습니다.
#
# LeNet-5: CNN의 상업적 적용
#   - 1998년: 얀 르쿤(Yann LeCun)과 그의 동료들은 손글씨 숫자 인식을 위한 CNN 아키텍처인 LeNet-5를 개발했습니다. 이는 실제 응용 프로그램에서 CNN을 사용한 첫 사례 중 하나로, 특히 은행에서 손글씨로 쓴 숫자를 인식하는 데 사용되었습니다.
#
# AlexNet: 딥러닝의 부흥
#   - 2012년: 알렉스 크리제브스키, 이야 화이트, 제프리 힌튼이 개발한 AlexNet은 이미지넷 대회(ILSVRC)에서 우승하며 딥러닝의 가능성을 전 세계에 알렸습니다. AlexNet은 깊이, ReLU 활성화 함수, 드롭아웃 등 혁신적인 기술을 통해 이전 모델들을 크게 앞서는 성능을 보였습니다.
# VGG, GoogLeNet, ResNet: 깊이와 효율성의 증가
#   - 2014년: VGGNet은 단순하고 깊은 아키텍처를 통해 높은 성능을 달성했습니다. 동시에, GoogLeNet(또는 Inception 모델)은 계산 자원을 효율적으로 사용하면서도 성능을 유지하는 방법을 제시했습니다.
#   - 2015년: ResNet은 잔차 연결(residual connections)을 도입함으로써 깊은 네트워크의 학습 문제를 해결했습니다. 이를 통해 100층을 넘어서는 아주 깊은 네트워크를 성공적으로 학습할 수 있게 되었습니다.
# 이후의 발전
#   - 2015년 이후: CNN 아키텍처는 계속해서 발전해 왔습니다. DenseNet, MobileNets, EfficientNet 등은 계산 효율성과 성능을 더욱 향상시켰습니다. 또한, Attention 메커니즘과 같은 새로운 개념이 도입되어, 네트워크가 이미지의 중요한 부분에 집중할 수 있게 되었습니다.
# 현재와 미래
#   - CNN은 이미지 분류, 객체 탐지, 세그멘테이션 등 다양한 컴퓨터 비전 작업에서 핵심적인 역할을 하고 있습니다. 최근에는 자연어 처리(NLP)와 음성 인식 등 다른 분야에도 영향을 미치고 있습니다. 예를 들어 이미지 분류는 이미지 전체를 분석하여 하나의 레이블을 할당하는 작업이라면, 객체 탐지는 이미지 내에서 여러 객체를 식별하고, 각 객체의 위치(보통 경계 상자(bounding boxes)로 표시)와 클래스를 예측하는 과정입니다.
#
# CNN의 발전 과정은 딥러닝 및 인공지능 분야의 급속한 진전을 상징하며, 계속해서 새로운 연구와 혁신이 이루어지고 있습니다. 이러한 발전은 기술의 한계를 넓히고, 다양한 실제 문제를 해결하는 데 크게 기여하고 있습니다.

# %% [markdown]
# ### CNN 모델의 발전
#
# * 1998: LeNet – Gradient-based Learning Applied to Document Recognition
# * 2012: AlexNet – ImageNet Classification with Deep Convolutional Neural Network
# * **2014: VggNet – Very Deep Convolutional Networks for Large-Scale Image Recognition**
# * **2014: GooLeNet – Going Deeper with Convolutions**
# * 2014: SppNet – Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition
# * **2015: ResNet – Deep Residual Learning for Image Recognition**
# * **2016: Xception – Xception: Deep Learning with Depthwise Separable Convolutions**
# * **2017: MobileNet – MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Application**
# * **2017: DenseNet – Densely Connected Convolutional Networks**
# * 2017: SeNet – Squeeze and Excitation Networks
# * 2017: ShuffleNet – ShuffleNet: An Extremely Efficient Convolutional Neural Network for Mobile Devices
# * **2018: NasNet – Learning Transferable Architectures for Scalable Image Recognition**
# * 2018: Bag of Tricks – Bag of Tricks for Image Classification with Convolutional Neural Networks
# * **2019: EfficientNet – EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks**

# %% [markdown]
# ### LeNet-5
# - 초기 합성곱 신경망(Convolutional Neural Network, CNN) 중 하나로, 1998년에 얀 르쿤(Yann LeCun)과 그의 연구팀에 의해 개발되었습니다. LeNet-5는 손글씨 숫자 인식을 목적으로 만들어졌으며, 특히 미국 우편 서비스에서 손글씨 우편 번호를 자동으로 인식하는 데 사용되었습니다. 이 모델은 딥러닝과 CNN의 초기 성공 사례 중 하나로 꼽히며, 후속 CNN 아키텍처의 발전에 중요한 영향을 미쳤습니다.
# - LeNet-5는 복잡하지 않은 망을 이용하여 (당시 기준)높은 성능을 보여주었을 뿐만 아니라 Convolutional layer와 pooling의 조합을 반복하는 현대적인 CNN 구조를 제안했다는 점에서 의미가 있는 모델
# - https://velog.io/@woojinn8/CNN-Network-1.-LeNet
#
# LeNet-5의 구조
#
# - 레이어 구성: LeNet-5는 대략적으로 7개의 레이어로 구성되어 있으며, 이 중 3개는 합성곱 레이어(Convolutional layers), 2개는 풀링 레이어(Pooling layers, 당시에는 서브샘플링 레이어라고 불렀음), 그리고 2개는 완전 연결 레이어(Fully connected layers)입니다. 이 레이어들은 손글씨 숫자의 특징을 추출하고, 이를 기반으로 숫자를 분류하는 데 사용됩니다.
#
# - 합성곱과 풀링: LeNet-5는 합성곱 레이어에서 여러 필터를 사용하여 이미지의 특징을 추출합니다. 이후, 풀링 레이어에서는 이 특징의 공간 크기를 줄이며, 변형에 대한 내성을 증가시킵니다.
#
# - 활성화 함수: LeNet-5에서는 시그모이드 함수와 하이퍼볼릭 탄젠트(tanh) 함수를 활성화 함수로 사용했습니다. 이는 당시 널리 사용되던 선택지였으며, 현재는 ReLU(Rectified Linear Unit) 함수 등 더 효율적인 활성화 함수들이 널리 사용되고 있습니다.
#
# - 출력층: 마지막 완전 연결 레이어는 소프트맥스 활성화 함수를 사용하여, 각 클래스(여기서는 0부터 9까지의 숫자)에 대한 확률을 출력합니다. 이를 통해 모델은 주어진 입력 이미지가 어떤 숫자를 나타내는지 예측합니다.
#
#   <img src="https://miro.medium.com/max/4308/1*1TI1aGBZ4dybR6__DI9dzA.png">
#   <center>[LeNet-5 구조]</center>

# %% [markdown]
# ### VGGNet
# 2014년 옥스퍼드 대학의 Visual Geometry Group에 의해 개발된 합성곱 신경망(Convolutional Neural Network, CNN) 아키텍처입니다. 이 모델은 ImageNet 대회(ILSVRC)에서 뛰어난 성능을 보여주며 광범위한 인기를 얻었습니다. VGGNet의 핵심 특징은 그것의 단순함과 깊이에 있습니다. 이 모델은 여러 층의 작은 크기(3x3)의 필터로 구성된 합성곱 층과, 몇 개의 완전 연결된 층으로 구성되어 있습니다.
#
# [ 주요 특징 ]
# - 작은 크기의 필터 사용: VGGNet은 모든 합성곱 층에서 3x3 크기의 필터를 사용합니다. 이 작은 필터 크기를 통해 모델의 깊이를 증가시킬 수 있으며, 이는 복잡한 특징을 더 잘 학습할 수 있게 해줍니다.
#
# - 채널 수의 증가: 네트워크가 깊어질수록 합성곱 층의 채널 수가 두 배씩 증가합니다. 이는 네트워크가 더 복잡한 특징을 학습할 수 있도록 해줍니다.
#
# - 동일한 스트라이드와 패딩 사용: 모든 합성곱 층에서 스트라이드(stride) 1을, 패딩(padding) 'same'을 사용하여 입력과 출력의 공간 차원을 유지합니다.
#
# - 맥스 풀링(Max Pooling) 층: 각 합성곱 층 블록 뒤에는 2x2 크기와 스트라이드 2를 가진 맥스 풀링 층이 있어, 특징 맵의 차원을 줄입니다.

# %% [markdown]
# - VGG-16 아키텍쳐
#
#   <br>
#
#   <img src="https://neurohive.io/wp-content/uploads/2018/11/vgg16.png">
#   <center>VGG-16 아키텍쳐</center>
#
#   <sub>[이미지 출처] https://neurohive.io/en/popular-networks/vgg16/ </sub>
#
#
# <br>
#
# - (참고) ILSVRC의 주요 분류 metric 중 하나는 `top-5`
#
#   - 상위 5개 예측 안에 정확한 클래스가 포함되면 제대로 예측한 것으로 간주
#
#   - 일반적인 `top-k` metric의 특정 케이스

# %%
from tensorflow.keras.applications import VGG16
vgg_net = VGG16(include_top=True, weights='imagenet',
                input_tensor=None, input_shape=None,
                pooling=None, classes=1000)
# Out:
# ...
# 553467096/553467096 [==============================] - 3s 0us/step

# %%
vgg_net.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# vgg16과 vgg19의 차이
#
# VGG19는 VGG16에 비해 합성곱 레이어가 추가되어, 더 깊은 구조를 가지고 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

vgg_net = VGG19(include_top=True, weights='imagenet',
                input_tensor=None, input_shape=None,
                pooling=None, classes=1000)

# %%
vgg_net.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
# ...

# %% [markdown]
# * dog.jpg (https://www.publicdomainpictures.net/pictures/250000/nahled/dog-beagle-portrait.jpg)

# %%
# !wget -O dog.jpg https://www.publicdomainpictures.net/pictures/250000/nahled/dog-beagle-portrait.jpg
# Out:
# --2024-03-11 06:43:11--  https://www.publicdomainpictures.net/pictures/250000/nahled/dog-beagle-portrait.jpg
# Resolving www.publicdomainpictures.net (www.publicdomainpictures.net)... 104.20.123.60, 172.67.1.236, 104.20.122.60, ...
# Connecting to www.publicdomainpictures.net (www.publicdomainpictures.net)|104.20.123.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88498 (86K) [image/jpeg]
# Saving to: ‘dog.jpg’
#
# dog.jpg             100%[===================>]  86.42K  --.-KB/s    in 0.007s
#
# 2024-03-11 06:43:11 (12.1 MB/s) - ‘dog.jpg’ saved [88498/88498]

# %%
# !ls
# Out:
# dog.jpg  plane.jpg  sample_data

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

img = tf.keras.preprocessing.image.load_img('dog.jpg', target_size=(224,224))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = vgg_net.predict(x)
print(decode_predictions(preds))
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[('n02088364', 'beagle', 0.8385744), ('n02089973', 'English_foxhound', 0.08904663), ('n02089867', 'Walker_hound', 0.062378537), ('n02088238', 'basset', 0.0046153953), ('n02088632', 'bluetick', 0.003376647)]]

# %% [markdown]
# ### GoogLeNet, Inception 모듈
# - GoogLeNet은 2014년 ImageNet Large-Scale Visual Recognition Challenge (ILSVRC)에서 우승한 심층 합성곱 신경망(Convolutional Neural Network, CNN) 아키텍처입니다. 이 모델은 주로 Inception 모듈이라는 독특한 구성 요소를 통해 인식되며, 효율적인 계산과 깊이(레이어의 수)를 늘리면서도 매개변수의 수를 상대적으로 줄이는 것을 목표로 합니다.
# - Inception 모듈의 핵심 아이디어는 네트워크가 스스로 가장 적합한 합성곱 필터(크기)를 학습할 수 있게 하는 것입니다. 전통적인 CNN 아키텍처에서는 개발자가 필터의 크기(예: 3x3, 5x5 등)를 사전에 결정해야 합니다. 그러나 Inception 모듈 내에서는 여러 다른 크기의 필터를 병렬로 배치하여, 네트워크가 한 레이어 내에서 여러 크기의 특징을 동시에 학습할 수 있도록 합니다. 이는 네트워크가 다양한 스케일의 특징을 더 잘 포착할 수 있게 해줍니다.
# - GoogLeNet의 특징
#   - GoogLeNet은 여러 개의 Inception 모듈을 포함하며, 깊이가 있으면서도 효율적인 모델을 구현합니다. 모델의 이름은 Google과 LeNet의 조합으로, 이는 구글이 개발에 기여했으며, 초기 CNN 중 하나인 LeNet에 대한 경의를 표하는 의미입니다.
#   - 깊이와 너비: GoogLeNet은 매우 깊은 아키텍처를 가지고 있지만, Inception 모듈 덕분에 필요한 매개변수의 수를 크게 줄일 수 있습니다.
#   - 계산 효율성: Inception 모듈은 다양한 크기의 필터를 병렬로 사용함으로써, 모델이 한 번의 순전파에서 다양한 크기의 특징을 학습할 수 있게 해줍니다

# %% [markdown]
# GoogLeNet, Inception 모듈
#
# - VGGNet을 제치고 같은 해 분류 과제에서 1등을 차지
#
# - 인셉션 블록이라는 개념을 도입하여, **인셉션 네트워크(Inception Network)**라고도 불림
#
#
#   <img src="https://miro.medium.com/max/2800/0*rbWRzjKvoGt9W3Mf.png">
#
#   <sub>[이미지 출처] https://medium.com/analytics-vidhya/cnns-architectures-lenet-alexnet-vgg-googlenet-resnet-and-more-666091488df5</sub>
#
#   <br>
#
# - 특징
#
#   - CNN 계산 용량을 최적화하는 것을 고려
#
#   - 전형적인 합성곱, 풀링 계층으로 시작하고, 이 정보는 9개의 인셉션 모듈 스택을 통과
#     해당 모듈을 하위 네트워크라고도 함
#
#   - 각 모듈에서 입력 특징 맵은 서로 다른 계층으로 구성된 4개의 병렬 하위 블록에 전달되고, 이를 서로 다시 연결
#
#   - 모든 합성곱과 풀링 계층의 padding옵션은 "SAME"이며 `stride=1`,
#     활성화 함수는 `ReLU` 사용
#
# - 기여
#
#   - 규모가 큰 블록과 병목을 보편화
#
#   - 병목 계층으로 1x1 합성곱 계층 사용
#
#   - 완전 연결 계층 대신 풀링 계층 사용
#
#   - 중간 소실로 경사 소실 문제 해결
#
#   <img src="https://norman3.github.io/papers/images/google_inception/f01.png">
#
#   <sub>[이미지 출처] https://norman3.github.io/papers/docs/google_inception.html</sub>

# %%
from keras.applications.inception_v3 import InceptionV3, preprocess_input, decode_predictions

inception = InceptionV3(include_top=True, weights='imagenet',
               input_tensor=None, input_shape=None,
               pooling=None, classes=1000)
inception.summary()
# Out:
# ...
# 96112376/96112376 [==============================] - 0s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 149, 149, 32)         864       ['input_3[0][0]']
#
#  batch_normalization (Batch  (None, 149, 149, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 149, 149, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 147, 147, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 147, 147, 32)         0         ['batch_normalization_1[0][0]'
# ...

# %% [markdown]
# * fish.jpg (https://upload.wikimedia.org/wikipedia/commons/7/7a/Goldfish_1.jpg)

# %%
# !wget -O fish.jpg https://upload.wikimedia.org/wikipedia/commons/7/7a/Goldfish_1.jpg
# Out:
# --2024-03-11 06:51:54--  https://upload.wikimedia.org/wikipedia/commons/7/7a/Goldfish_1.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4648040 (4.4M) [image/jpeg]
# Saving to: ‘fish.jpg’
#
# fish.jpg            100%[===================>]   4.43M  21.3MB/s    in 0.2s
#
# 2024-03-11 06:51:54 (21.3 MB/s) - ‘fish.jpg’ saved [4648040/4648040]

# %%
img = tf.keras.preprocessing.image.load_img('fish.jpg', target_size=(299,299))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = inception.predict(x)
print(decode_predictions(preds))
# Out:
# 1/1 [==============================] - 2s 2s/step
# [[('n01443537', 'goldfish', 0.97486055), ('n02701002', 'ambulance', 0.0023212507), ('n02606052', 'rock_beauty', 0.0019220157), ('n02607072', 'anemone_fish', 0.0006687698), ('n09256479', 'coral_reef', 0.00043373124)]]

# %% [markdown]
# ### ResNet - 잔차 네트워크
# ResNet, 또는 Residual Network는 깊은 신경망을 효율적으로 학습시키기 위해 개발된 구조 중 하나로, 2015년에 Microsoft Research의 Kaiming He, Xiangyu Zhang, Shaoqing Ren, 그리고 Jian Sun에 의해 제안되었습니다. ResNet은 그 당시의 깊은 신경망이 직면했던 주요 문제 중 하나인 소실되는 그래디언트(vanishing gradient) 문제를 해결하기 위해 고안되었습니다. 이 아키텍처는 매우 깊은 네트워크를 효과적으로 학습할 수 있도록 하여, 여러 벤치마크에서 뛰어난 성능을 달성했습니다.
# - ResNet의 핵심은 잔차 블록(Residual Block)에 있습니다. 각 잔차 블록은 입력을 직접적으로 그 다음 레이어의 출력에 더함으로써, 레이어가 "잔차"를 학습하도록 합니다. 이러한 접근 방식은 레이어가 입력을 그대로 전달하는 것(identical mapping)을 학습하는 것이 레이어가 제로 매핑(zero mapping)을 학습하는 것보다 쉽다는 가정 하에 기반합니다. 이를 통해, 네트워크가 깊어질수록 성능이 향상되는 것을 목표로 합니다.
#
# - ResNet의 특징
#
# 깊은 네트워크의 효율적 학습: ResNet은 100층을 넘어서는 매우 깊은 네트워크를 성공적으로 학습할 수 있게 하여, 그 당시 기존의 신경망보다 훨씬 깊은 구조를 가능하게 했습니다.
#   - 잔차 학습(Residual Learning): 각 잔차 블록은 입력 특성을 출력에 직접 더함으로써, 레이어가 출력해야 하는 변화량(잔차)만을 학습하게 합니다. 이는 학습 과정을 안정화시키고, 소실되는 그래디언트 문제를 완화합니다.
#
#   - 다양한 변형: ResNet 아키텍처는 그 깊이에 따라 여러 변형이 있습니다. 예를 들어, ResNet-34, ResNet-50, ResNet-101, ResNet-152 등이 있으며, 이 숫자는 네트워크에 있는 레이어의 수를 나타냅니다. ResNet-50 이상의 모델에서는 병목 레이어(bottleneck layer)를 사용하여 계산 효율성을 개선합니다.
#
#   - 전이 학습(Transfer Learning)에의 활용: ResNet은 다양한 시각적 태스크에 대해 사전 학습된 모델을 제공합니다. 이를 통해, 적은 양의 데이터로도 높은 성능의 모델을 개발할 수 있습니다.

# %% [markdown]
#  <img src="https://miro.medium.com/max/1200/1*6hF97Upuqg_LdsqWY6n_wg.png">
#
#   <sub>[이미지 출처] https://towardsdatascience.com/review-resnet-winner-of-ilsvrc-2015-image-classification-localization-detection-e39402bfa5d8</sub>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions

resnet = ResNet50(include_top=True, weights='imagenet',
               input_tensor=None, input_shape=None,
               pooling=None, classes=1000)
resnet.summary()
# Out:
# ...
# 102967424/102967424 [==============================] - 1s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_4[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
# ...

# %% [markdown]
# * bee.jpg (https://upload.wikimedia.org/wikipedia/commons/4/4d/Apis_mellifera_Western_honey_bee.jpg)

# %%
# !wget -O bee.jpg https://upload.wikimedia.org/wikipedia/commons/4/4d/Apis_mellifera_Western_honey_bee.jpg
# Out:
# --2024-03-11 06:53:12--  https://upload.wikimedia.org/wikipedia/commons/4/4d/Apis_mellifera_Western_honey_bee.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2421052 (2.3M) [image/jpeg]
# Saving to: ‘bee.jpg’
#
# bee.jpg             100%[===================>]   2.31M  --.-KB/s    in 0.1s
#
# 2024-03-11 06:53:13 (15.4 MB/s) - ‘bee.jpg’ saved [2421052/2421052]

# %%
img = tf.keras.preprocessing.image.load_img('bee.jpg', target_size=(224,224))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = resnet.predict(x)
print(decode_predictions(preds))
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[('n02206856', 'bee', 0.9990947), ('n03530642', 'honeycomb', 0.00056537177), ('n02190166', 'fly', 0.00014305624), ('n02727426', 'apiary', 0.00010237467), ('n02219486', 'ant', 5.733068e-05)]]

# %% [markdown]
# ### Xception
#
# * Inception module을 이용하여 depthwise convolution 적용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.applications.xception import Xception, preprocess_input, decode_predictions

xception = Xception(include_top=True, weights='imagenet',
               input_tensor=None, input_shape=None,
               pooling=None, classes=1000)
xception.summary()
# Out:
# ...
# 91884032/91884032 [==============================] - 1s 0us/step
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_6 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['input_6[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
# ...

# %% [markdown]
# * beaver.jpg (https://upload.wikimedia.org/wikipedia/commons/6/6b/American_Beaver.jpg)

# %%
# !wget -O beaver.jpg https://upload.wikimedia.org/wikipedia/commons/6/6b/American_Beaver.jpg
# Out:
# --2024-03-11 07:06:02--  https://upload.wikimedia.org/wikipedia/commons/6/6b/American_Beaver.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187016 (183K) [image/jpeg]
# Saving to: ‘beaver.jpg’
#
# beaver.jpg          100%[===================>] 182.63K  --.-KB/s    in 0.06s
#
# 2024-03-11 07:06:02 (3.16 MB/s) - ‘beaver.jpg’ saved [187016/187016]

# %%
img = tf.keras.preprocessing.image.load_img('beaver.jpg', target_size=(299,299))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = xception.predict(x)
print(decode_predictions(preds))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ca66677e440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 906ms/step
# [[('n02363005', 'beaver', 0.82418865), ('n02361337', 'marmot', 0.04998864), ('n02493509', 'titi', 0.004341773), ('n02442845', 'mink', 0.0016982016), ('n02444819', 'otter', 0.0016949091)]]

# %% [markdown]
# ### MobileNet
#
# * 성능보다 모델의 크기 또는 연산 속도 감소
# * Depthwise conv와 Pointwise conv 사이에도 batch normalization과 ReLU를 삽입
# * Conv layer를 활용한 모델과 정확도는 비슷하면서 계산량은 9배, 파라미터 수는 7배 줄임

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.applications.mobilenet import MobileNet, preprocess_input, decode_predictions

mobilenet = MobileNet(include_top=True, weights='imagenet',
               input_tensor=None, input_shape=None,
               pooling=None, classes=1000)
mobilenet.summary()
# Out:
# ...
# 17225924/17225924 [==============================] - 0s 0us/step
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
# ...

# %% [markdown]
# * crane.jpg (https://p1.pxfuel.com/preview/42/50/534/europe-channel-crane-harbour-crane-harbour-cranes-cranes-transport.jpg)

# %%
# !wget -O crane.jpg https://p1.pxfuel.com/preview/42/50/534/europe-channel-crane-harbour-crane-harbour-cranes-cranes-transport.jpg
# Out:
# --2024-03-11 07:07:33--  https://p1.pxfuel.com/preview/42/50/534/europe-channel-crane-harbour-crane-harbour-cranes-cranes-transport.jpg
# Resolving p1.pxfuel.com (p1.pxfuel.com)... 172.67.151.78, 104.21.12.22, 2606:4700:3037::ac43:974e, ...
# Connecting to p1.pxfuel.com (p1.pxfuel.com)|172.67.151.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86911 (85K) [image/jpeg]
# Saving to: ‘crane.jpg’
#
# crane.jpg           100%[===================>]  84.87K  --.-KB/s    in 0.007s
#
# 2024-03-11 07:07:34 (11.6 MB/s) - ‘crane.jpg’ saved [86911/86911]

# %%
img = tf.keras.preprocessing.image.load_img('crane.jpg', target_size=(224,224))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = mobilenet.predict(x)
print(decode_predictions(preds))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ca72472a200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 484ms/step
# [[('n03126707', 'crane', 0.96338284), ('n03216828', 'dock', 0.027054528), ('n03240683', 'drilling_platform', 0.0047102757), ('n03344393', 'fireboat', 0.0022202157), ('n03532672', 'hook', 0.0005047582)]]

# %% [markdown]
# ### DenseNet
#
# * 각 층은 모든 앞 단계에서 올 수 있는 지름질 연결 구성
# * 특징지도의 크기를 줄이기 위해 풀링 연산 적용 필요
# * 밀집 블록(dense block)과 전이층(transition layer)으로 구성
# * 전이층 : 1x1 컨볼루션과 평균값 풀링(APool)으로 구성
#
# <img src="https://oi.readthedocs.io/en/latest/_images/cnn_vs_resnet_vs_densenet.png" width="700">

# %%
from keras.applications.densenet import DenseNet201, preprocess_input, decode_predictions

densenet = DenseNet201(include_top=True, weights='imagenet',
               input_tensor=None, input_shape=None,
               pooling=None, classes=1000)
densenet.summary()
# Out:
# ...
# 82524592/82524592 [==============================] - 1s 0us/step
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_8[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#
# ...

# %% [markdown]
# * zebra.jpg (https://upload.wikimedia.org/wikipedia/commons/f/f0/Zebra_standing_alone_crop.jpg)

# %%
# !wget -O zebra.jpg https://upload.wikimedia.org/wikipedia/commons/f/f0/Zebra_standing_alone_crop.jpg
# Out:
# --2024-03-11 07:09:00--  https://upload.wikimedia.org/wikipedia/commons/f/f0/Zebra_standing_alone_crop.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188036 (184K) [image/jpeg]
# Saving to: ‘zebra.jpg’
#
# zebra.jpg           100%[===================>] 183.63K  --.-KB/s    in 0.05s
#
# 2024-03-11 07:09:00 (3.38 MB/s) - ‘zebra.jpg’ saved [188036/188036]

# %%
img = tf.keras.preprocessing.image.load_img('zebra.jpg', target_size=(224,224))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = densenet.predict(x)
print(decode_predictions(preds))
# Out:
# 1/1 [==============================] - 3s 3s/step
# [[('n02391049', 'zebra', 0.9299578), ('n01518878', 'ostrich', 0.020056538), ('n02423022', 'gazelle', 0.012069016), ('n02397096', 'warthog', 0.004491635), ('n02422106', 'hartebeest', 0.0031249507)]]

# %% [markdown]
# ## NasNet
#
# * 신경망 구조를 사람이 설계하지 않고, complete search를 통해 자동으로 구조를 찾아냄
# * 네트워크를 구성하는 layer를 하나씩 탐색하는 NAS 방법 대신, NasNet은 Convolution cell 단위를 먼저 추정하고, 이들을 조합하여 전체 네트워크 구성
# * 성능은 높지만, 파라미터 수와 연산량은 절반 정도로 감소

# %%
from keras.applications.nasnet import NASNetLarge, preprocess_input,decode_predictions
nasnet = NASNetLarge(include_top=True, weights='imagenet',
                     input_tensor=None, input_shape=None,
                     pooling=None, classes=1000)
nasnet.summary()
# Out:
# ...
# 359748576/359748576 [==============================] - 3s 0us/step
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_9 (InputLayer)        [(None, 331, 331, 3)]        0         []
#
#  stem_conv1 (Conv2D)         (None, 165, 165, 96)         2592      ['input_9[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 165, 165, 96)         384       ['stem_conv1[0][0]']
#  on)
#
#  activation_94 (Activation)  (None, 165, 165, 96)         0         ['stem_bn1[0][0]']
#
#  reduction_conv_1_stem_1 (C  (None, 165, 165, 42)         4032      ['activation_94[0][0]']
#  onv2D)
#
#  reduction_bn_1_stem_1 (Bat  (None, 165, 165, 42)         168       ['reduction_conv_1_stem_1[0][0
#  chNormalization)                                                   ]']
#
# ...

# %% [markdown]
# * notebook.jpg (https://cdn.pixabay.com/photo/2016/07/11/03/35/macbook-1508998_1280.jpg)

# %%
# !wget -O notebook.jpg https://cdn.pixabay.com/photo/2016/07/11/03/35/macbook-1508998_1280.jpg
# Out:
# --2024-03-11 07:10:33--  https://cdn.pixabay.com/photo/2016/07/11/03/35/macbook-1508998_1280.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.40.96, 172.64.147.160, 2606:4700:4400::ac40:93a0, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.40.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 270631 (264K) [binary/octet-stream]
# Saving to: ‘notebook.jpg’
#
# notebook.jpg        100%[===================>] 264.29K  --.-KB/s    in 0.1s
#
# 2024-03-11 07:10:34 (2.39 MB/s) - ‘notebook.jpg’ saved [270631/270631]

# %%
img = tf.keras.preprocessing.image.load_img('notebook.jpg', target_size=(331,331))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = nasnet.predict(x)
print(decode_predictions(preds))
# Out:
# 1/1 [==============================] - 5s 5s/step
# [[('n03832673', 'notebook', 0.79389566), ('n03642806', 'laptop', 0.048168), ('n04264628', 'space_bar', 0.034221098), ('n03085013', 'computer_keyboard', 0.020011393), ('n03777754', 'modem', 0.011280294)]]

# %% [markdown]
# ### EfficientNet
#
# * EfficientNetB0인 작은 모델에서 주어진 Task에 최적화된 구조로 수정해나가는 형태
# * 복잡한 Task에 맞춰 모델의 Capacity를 늘리기 위해 Wide Scaling, Deep Scaling, 그리고 Resolution Scaling을 사용
# * EfficientNet은 Wide, Deep, Resolution을 함께 고려하는 Compound Scaling을 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.applications.efficientnet import EfficientNetB1, preprocess_input,decode_predictions
efficientnet = EfficientNetB1(include_top=True, weights='imagenet',
                     input_tensor=None, input_shape=None,
                     pooling=None, classes=1000)
efficientnet.summary()
# Out:
# Model: "efficientnetb1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_5 (InputLayer)        [(None, 240, 240, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 240, 240, 3)          0         ['input_5[0][0]']
#
#  normalization (Normalizati  (None, 240, 240, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 240, 240, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 241, 241, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 120, 120, 32)         864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 120, 120, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 120, 120, 32)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %% [markdown]
# * plane.jpg (https://upload.wikimedia.org/wikipedia/commons/1/12/Plane-in-flight.jpg)

# %%
# !wget -O plane.jpg https://upload.wikimedia.org/wikipedia/commons/1/12/Plane-in-flight.jpg
# Out:
# --2024-03-11 07:02:28--  https://upload.wikimedia.org/wikipedia/commons/1/12/Plane-in-flight.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 487351 (476K) [image/jpeg]
# Saving to: ‘plane.jpg’
#
# plane.jpg           100%[===================>] 475.93K  --.-KB/s    in 0.08s
#
# 2024-03-11 07:02:28 (5.50 MB/s) - ‘plane.jpg’ saved [487351/487351]

# %%
img = tf.keras.preprocessing.image.load_img('plane.jpg', target_size=(240,240))
plt.imshow(img)
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape(1,x.shape[0],x.shape[1],x.shape[2])
x = preprocess_input(x)
preds = efficientnet.predict(x)
print(decode_predictions(preds))
# Out:
# 1/1 [==============================] - 3s 3s/step
# [[('n02690373', 'airliner', 0.7583577), ('n04592741', 'wing', 0.10027363), ('n04552348', 'warplane', 0.083563745), ('n04266014', 'space_shuttle', 0.0064463136), ('n02692877', 'airship', 0.00090382044)]]

# %% [markdown]
# ### 객체 탐지
# - 합성곱 신경망(CNN)의 발전은 객체 탐지 분야에 큰 영향을 미쳤습니다. 객체 탐지는 이미지나 비디오 내에서 객체의 위치를 식별하고 분류하는 과정을 포함합니다. CNN이 이미지 분류에서 뛰어난 성능을 보임에 따라, 연구자들은 이를 객체 탐지에 적용하기 시작했습니다. CNN을 사용한 객체 탐지의 발전 과정은 크게 두 가지 방향으로 나뉩니다: 하나는 영역 기반 CNN(R-CNN 계열)을 사용한 접근법이고, 다른 하나는 단일 신경망을 사용한 접근법(YOLO, SSD 등)입니다.
#
# 1. 영역 기반 CNN (R-CNN과 그 후속 연구)
#
#   R-CNN (Regions with CNN features)
#   - R-CNN(Regions with CNN features)이 영역 기반(Region-based)이란 것은 이 모델이 이미지 내에서 객체가 있을 법한 위치를 식별하는 "영역" 또는 "후보 영역"(candidate regions)을 먼저 추출한 뒤, 각 영역에 대해 CNN을 적용하여 특징을 추출하고 객체를 분류한다는 의미입니다. 이 접근 방식은 객체 탐지를 위해 이미지 전체를 한 번에 처리하는 대신, 이미지 내의 특정 영역들을 중심으로 분석을 집중함으로써 보다 효율적으로 객체를 식별하고 분류하려는 목적을 가지고 있습니다.
#   - R-CNN은 이미지에서 후보 영역(proposal regions)을 추출한 후, 각 영역에 대해 CNN을 적용하여 특징을 추출하고, 마지막에 SVM(서포트 벡터 머신)을 사용해 객체를 분류합니다. 그러나 이 방법은 후보 영역을 처리하는 데 많은 계산이 필요하고, 속도가 느린 단점이 있습니다.
#
#   Fast R-CNN
#   - Fast R-CNN은 R-CNN의 단점을 개선하기 위해 도입되었습니다. 전체 이미지에 대해 한 번에 CNN을 적용하고, 추출된 특징 맵(feature map)에서 직접 후보 영역에 해당하는 특징을 추출하여 처리합니다. 이는 계산 효율성을 크게 향상시켰습니다.
#
#   Faster R-CNN
#   - Faster R-CNN은 영역 제안 과정 자체를 신경망으로 대체한 것으로, Region Proposal Network(RPN)를 도입하여 후보 영역 추출을 더욱 가속화했습니다. Faster R-CNN은 객체 탐지 분야에서 중요한 이정표로 여겨지며, 높은 정확도와 상대적으로 빠른 처리 속도를 제공합니다.
#
# 2. 단일 신경망을 사용한 접근법
#
#   YOLO (You Only Look Once)
#   - YOLO는 이미지 전체를 단일 신경망에 통과시켜, 객체의 분류와 위치를 한 번에 예측합니다. 이 접근법은 빠른 처리 속도를 제공하며, 실시간 객체 탐지에 적합합니다. YOLO는 이미지를 격자로 나누고, 각 격자 셀에 대해 객체의 존재 확률과 경계 상자(bounding box)를 예측합니다.
#
#   SSD (Single Shot MultiBox Detector)
#   - SSD는 다양한 크기의 특징 맵에서 다중 스케일의 객체를 탐지할 수 있도록 설계된 또 다른 단일 신경망 기반 접근법입니다. SSD는 YOLO와 비슷하게 속도와 정확도 사이에서 균형을 맞추며, 다양한 크기의 객체를 더 잘 탐지할 수 있습니다.

# %% [markdown]
# ### 객체 탐지에서 가장 많이 사용되는 모델
# YOLO (You Only Look Once) Series
# - 이유: YOLO는 이미지 전체를 단일 신경망을 통해 처리하여, 객체의 분류와 위치를 한 번에 예측합니다. 이 모델은 빠른 처리 속도를 제공하여 실시간 응용 프로그램에 매우 적합합니다. YOLO는 높은 정확도와 빠른 속도의 균형 때문에 널리 사용됩니다.
#
# Faster R-CNN
# - 이유: Faster R-CNN은 정확도가 매우 높은 객체 탐지 모델로, Region Proposal Network (RPN)를 사용하여 후보 영역의 추출 속도를 대폭 향상시켰습니다. 정확한 객체 탐지와 분류를 요구하는 응용 프로그램에서 선호되며, 특히 정밀한 객체 탐지가 필요한 고해상도 이미지에서 강력한 성능을 발휘합니다.
#
# 모델이 널리 사용되는 이유
# - 성능: 높은 정확도와 빠른 추론 속도를 제공하여, 다양한 환경과 요구 사항을 만족시킵니다.
# - 유연성: 다양한 크기와 형태의 이미지에 적용할 수 있으며, 맞춤형 조정이 가능합니다.
# - 커뮤니티 지원: 널리 사용되는 모델은 대개 강력한 커뮤니티 지원을 받으며, 사전 훈련된 모델과 풍부한 학습 자료가 제공됩니다.
# - 응용 프로그램의 다양성: 이 모델들은 감시, 자율 주행 차량, 의료 영상 분석 등 다양한 분야에 적용 가능합니다.
#
# 결국, 특정 모델의 선택은 프로젝트의 목표, 필요한 정확도와 처리 속도, 사용 가능한 컴퓨팅 자원 등에 따라 달라집니다. 모델의 선정 과정에서는 이러한 요소들을 고려하여 최적의 선택을 해야 합니다.
